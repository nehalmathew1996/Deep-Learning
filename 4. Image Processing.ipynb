# %%
import tensorflow as tf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import cv2

# %%
# Reaading an image
img=cv2.imread('cameraman.png')
img
# Out:
# array([[[156, 156, 156],
#         [159, 159, 159],
#         [158, 158, 158],
#         ...,
#         [151, 151, 151],
#         [152, 152, 152],
#         [152, 152, 152]],
#
#        [[160, 160, 160],
#         [154, 154, 154],
#         [157, 157, 157],
#         ...,
#         [154, 154, 154],
#         [155, 155, 155],
#         [153, 153, 153]],
#
#        [[156, 156, 156],
#         [159, 159, 159],
#         [158, 158, 158],
#         ...,
#         [151, 151, 151],
#         [152, 152, 152],
#         [152, 152, 152]],
#
#        ...,
#
#        [[114, 114, 114],
#         [132, 132, 132],
#         [123, 123, 123],
#         ...,
#         [135, 135, 135],
#         [137, 137, 137],
#         [114, 114, 114]],
#
#        [[121, 121, 121],
#         [126, 126, 126],
#         [130, 130, 130],
#         ...,
#         [133, 133, 133],
#         [130, 130, 130],
#         [113, 113, 113]],
#
#        [[121, 121, 121],
#         [126, 126, 126],
#         [130, 130, 130],
#         ...,
#         [133, 133, 133],
#         [130, 130, 130],
#         [113, 113, 113]]], dtype=uint8)

# %%
# Ploting an image
plt.imshow(img,cmap='gray')

# %%
# Image Enhancement
# Brightness Improvement

img1=img+50
img1[img1>255]=255
plt.imshow(img1,cmap='gray')

# %%
# Contrast
imgn=img/255.
img2=5*np.log(imgn+1)
plt.imshow(img2,cmap='gray')
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
cheetha=cv2.imread('cheetha.jpg',0)
plt.imshow(cheetha)

# %%
plt.hist(cheetha.ravel(),128,[0,256])
plt.show()

# %%
img=cv2.imread('ballons.bmp')
plt.imshow(img)

# %%
plt.imshow(img[:,:,0])

# %%
plt.imshow(img[:,:,1])

# %%
plt.imshow(img[:,:,2])

# %%
img=cv2.imread('noisy_lung.jpg',0)
img.shape
# Out:
# (512, 512)

# %%
# Noise Processing Filter

img = cv2.imread('noisy_lung.jpg',0)
kernal=np.ones((7,7),dtype=float)/49

filt=cv2.filter2D(img,-1,kernal)

plt.imshow(img,cmap='gray')

# %%
plt.imshow(filt,cmap='gray')

# %%
# Edge Filter

img=cv2.imread('noisy_lung.jpg',0)
kernal=np.matrix('-1 -1 -1; -1 8 -1;-1 -1 -1')
filt=cv2.filter2D(img,-1,kernal)

plt.imshow(img,cmap='gray')

# %%
plt.imshow(filt,cmap='gray')

# %%
# Segmentation

img=cv2.imread('mri_tumor1.jpg',0)
plt.imshow(img,cmap='gray')

# %%
plt.hist(img.ravel(),256,[0,256])
plt.show()

# %%
img1=cv2.imread('mri_tumor1.jpg',0)
img1[img1>200]=255
img1[img1<200]=0
plt.imshow(img1,cmap='gray')

# %%
# Area
(img1!=0).sum()
# Out:
# 3637

# %%
# Max Height
(img!=0).sum(axis=0).max()
# Out:
# 387

# %%
# Max Width
(img1!=0).sum(axis=1).max()
# Out:
# 62
